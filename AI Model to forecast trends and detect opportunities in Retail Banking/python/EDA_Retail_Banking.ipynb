# %% [markdown]
# # Retail Banking

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# 1. Build an AI Model to forecast trends and detect opportunities in Retail Banking.

# %% [markdown]
# ## Data Analysis for the Solution

# %%
# install openpyxl to read .xlsx files.

# %pip install openpyxl

# %%
# importing initial libraries

import numpy as np
import pandas as pd

# %%
#import the warnings.

import warnings
warnings.filterwarnings('ignore')

# %%
# reading the first sheet (sheet index 0) from the Excel file (ODA Loan) and storing the information in the variable 'df'

data_path = "../dataset/DataSet17Dec2025.xlsx"
field_desc_path = "../dataset/FieldDesc.xlsx"

df = pd.read_excel(data_path, sheet_name=0)
field_desc = pd.read_excel(field_desc_path)

# %%
# getting the first look of the dataframe/structure info

structure_info = {
    "total_records": df.shape[0],
    "total_columns": df.shape[1],
    "dtypes": df.dtypes.astype(str)
}

structure_info, df.head(), field_desc.head()
# Out:
# ({'total_records': 17511,
#   'total_columns': 28,
#   'dtypes': ACCT_OPN_DATE         datetime64[ns]
#   SCHM_TYPE                     object
#   SANCT_LIM                    float64
#   COLLATERAL_TYPE               object
#   LOAN_TENURE_MONTHS           float64
#   REP_FREQ                      object
#   INTTRATE                     float64
#   PREPAYMENT_HIST               object
#   OVD_AMT                      float64
#   CUST_DOB              datetime64[ns]
#   MONTHLY_AVG_DEP              float64
#   FD_AMT                       float64
#   MONTHLY_AVG_CR_AMT           float64
#   MONTHLY_AVG_DR_AMT           float64
#   MONTHLY_NO_OF_TXNS           float64
#   DISTRICT                      object
#   PROVINCE                      object
#   PROFESSION                    object
#   RISK_RATING                   object
#   DORMANT_STATUS                object
#   NO_OF_QR_TXNS                float64
#   NO_OF_POS_TXNS               float64
#   FONELOAN_OS                  float64
#   CC_OS                        float64
#   MAPPED_FORACID                object
#   MAPPED_CIF_ID                 object
#   MAPPED_OP_AC                  object
#   AS_ON                 datetime64[ns]
#   dtype: object},
#    ACCT_OPN_DATE SCHM_TYPE   SANCT_LIM     COLLATERAL_TYPE  LOAN_TENURE_MONTHS  \
#  0    2022-12-12       LAA   750000.00  Immovable Property               120.0
#  1    2021-01-31       LAA    74601.87                 NaN                71.0
#  2    2021-03-21       LAA  1500000.00  Immovable Property               120.0
#  3    2021-09-27       LAA   700000.00  Immovable Property               120.0
#  4    2023-03-20       LAA  1000000.00                 NaN               120.0
#
#    REP_FREQ  INTTRATE PREPAYMENT_HIST   OVD_AMT   CUST_DOB  ...  RISK_RATING  \
#  0        M      7.75               N      0.00 1990-12-06  ...          LOW
#  1        M      8.50               N    362.93 1970-02-12  ...          LOW
#  2        M      7.75               N  17825.24 1980-02-24  ...          LOW
#  3        M      7.75               Y      0.00 1986-09-28  ...          LOW
#  4        M      2.75               N      0.00 1974-05-19  ...          LOW
#
#     DORMANT_STATUS  NO_OF_QR_TXNS  NO_OF_POS_TXNS  FONELOAN_OS CC_OS  \
#  0               A            NaN             NaN          NaN   NaN
#  1               A            NaN             NaN          NaN   NaN
#  2               A            NaN             NaN          NaN   NaN
#  3               A            NaN             NaN          NaN   NaN
#  4               A            NaN             NaN          NaN   NaN
#
#      MAPPED_FORACID MAPPED_CIF_ID MAPPED_OP_AC      AS_ON
#  0  AGG06M8CCAAAACI    RAIBBFJBAF  AGGBBAAFCDI 2025-11-30
#  1  AGG06M8CBAAAABJ    RAIAEIJEGG  AGGCAAACDIF 2025-11-30
#  2  AGG06M8CBAAAAEG    RAIAIEBIED  AGGBBAAECEI 2025-11-30
#  3  AGG06M8CBAAAAGE    RAIAJFHIBA  AGGBBAAEFIF 2025-11-30
#  4  AGG06M8CDAAAABJ    RAIBBJHFAF  AGGHBAAAAGA 2025-11-30
#
#  [5 rows x 28 columns],
#          ACCT_OPN_DATE    Account opened date
#  0           SCHM_TYPE            Scheme type
#  1           SANCT_LIM       Sanctioned limit
#  2     COLLATERAL_TYPE        Collateral type
#  3  LOAN_TENURE_MONTHS  Loan tenure in months
#  4            REP_FREQ    Repayment Frequency)

# %%
# checking the shape of the dataframe 'df'

df.shape
# Out:
# (17511, 28)

# %%
# Identify numerical and categorical variables

numerical_cols = df.select_dtypes(include=[np.number]).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()
date_cols = df.select_dtypes(include=['datetime64']).columns.tolist()

numerical_cols, categorical_cols, date_cols
# Out:
# (['SANCT_LIM',
#   'LOAN_TENURE_MONTHS',
#   'INTTRATE',
#   'OVD_AMT',
#   'MONTHLY_AVG_DEP',
#   'FD_AMT',
#   'MONTHLY_AVG_CR_AMT',
#   'MONTHLY_AVG_DR_AMT',
#   'MONTHLY_NO_OF_TXNS',
#   'NO_OF_QR_TXNS',
#   'NO_OF_POS_TXNS',
#   'FONELOAN_OS',
#   'CC_OS'],
#  ['SCHM_TYPE',
#   'COLLATERAL_TYPE',
#   'REP_FREQ',
#   'PREPAYMENT_HIST',
#   'DISTRICT',
#   'PROVINCE',
#   'PROFESSION',
#   'RISK_RATING',
#   'DORMANT_STATUS',
#   'MAPPED_FORACID',
#   'MAPPED_CIF_ID',
#   'MAPPED_OP_AC'],
#  ['ACCT_OPN_DATE', 'CUST_DOB', 'AS_ON'])

# %%
# Show the last few rows of a DataFrame

df.tail()
# Out:
#       ACCT_OPN_DATE SCHM_TYPE  SANCT_LIM COLLATERAL_TYPE  LOAN_TENURE_MONTHS  \
# 17506    2024-10-08       ODA        0.0             NaN                 NaN
# 17507    2025-07-03       ODA        0.0             NaN                 NaN
# 17508    2025-09-24       ODA        0.0             NaN                 NaN
# 17509    2025-11-04       ODA        0.0             NaN                 NaN
# 17510    2021-10-25       ODA        0.0             NaN                 NaN
#
#       REP_FREQ  INTTRATE PREPAYMENT_HIST  OVD_AMT   CUST_DOB  ...  \
# 17506      NaN       2.0               N      NaN 1998-12-21  ...
# 17507      NaN       2.0               N      NaN 1979-07-26  ...
# 17508      NaN       2.0               N      NaN 1996-06-01  ...
# 17509      NaN       2.0               N      NaN 1996-02-04  ...
# 17510      NaN       0.0               N      NaN 1900-01-01  ...
#
#        RISK_RATING  DORMANT_STATUS  NO_OF_QR_TXNS  NO_OF_POS_TXNS  \
# 17506          LOW               A            NaN             NaN
# 17507          LOW               A            NaN             NaN
# 17508          LOW               A            NaN             NaN
# 17509          LOW               A            NaN             NaN
# 17510          LOW               D            NaN             NaN
#
#        FONELOAN_OS CC_OS    MAPPED_FORACID MAPPED_CIF_ID      MAPPED_OP_AC  \
# 17506          NaN   NaN  CAHAJEJAIGAHHADJ    RAIAJEJAIG  CAHAJEJAIGAHHADJ
# 17507          NaN   NaN  CAHBGHGEAGAHHAIA    RABBGHGEAG  CAHBGHGEAGAHHAIA
# 17508          NaN   NaN  CAHAFBEHCIAHHAIH    RAIAFBEHCI  CAHAFBEHCIAHHAIH
# 17509          NaN   NaN  CAHBGCJCGJAHHAIJ    RABBGCJCGJ  CAHBGCJCGJAHHAIJ
# 17510          NaN   NaN       ACAHHAAAAEG    RAIAJHDHCE       ACAHHAAAAEG
#
#            AS_ON
# 17506 2025-09-30
# 17507 2025-09-30
# 17508 2025-09-30
# 17509 2025-09-30
# 17510 2025-09-30
#
# [5 rows x 28 columns]

# %%
# Randomly select 5 rows from the DataFrame

df.sample(5)
# Out:
#      ACCT_OPN_DATE SCHM_TYPE  SANCT_LIM COLLATERAL_TYPE  LOAN_TENURE_MONTHS  \
# 2101    2025-12-16       LAA  127153.82             NaN                 0.0
# 8097    2025-05-22       ODA       0.00             NaN                 NaN
# 4620    2021-07-10       LAA  177448.41             NaN                10.0
# 1618    2025-09-21       LAA   46250.77             NaN                 0.0
# 4968    2025-05-04       LAA    2260.00             NaN                 0.0
#
#      REP_FREQ  INTTRATE PREPAYMENT_HIST   OVD_AMT   CUST_DOB  ...  \
# 2101       QI      0.00               N       NaN 1974-10-26  ...
# 8097      NaN      7.75               N       NaN 1968-05-23  ...
# 4620        M      8.75               Y      0.00 1983-05-03  ...
# 1618       QI      9.25               N  46739.63 1974-04-18  ...
# 4968       QI      0.00               N   2260.00 1977-11-27  ...
#
#       RISK_RATING  DORMANT_STATUS  NO_OF_QR_TXNS  NO_OF_POS_TXNS  FONELOAN_OS  \
# 2101          LOW               A            NaN             NaN          NaN
# 8097          LOW               A            NaN             NaN          NaN
# 4620          LOW               A            NaN             NaN          NaN
# 1618          LOW               A            NaN             NaN          NaN
# 4968          LOW               A            NaN             NaN          NaN
#
#           CC_OS    MAPPED_FORACID MAPPED_CIF_ID      MAPPED_OP_AC      AS_ON
# 2101  126479.13   BAF22LNCFAAABDE    RAIAHABFCI       AABCFAAFBDJ 2025-10-31
# 8097        NaN  BHGBGFEEABABBBCD    RABBGFEEAB  BHGBGFEEABABBBCD 2025-11-30
# 4620        NaN  AFHAEHEGAJRTLAAH    RABAEHEGAJ  AFHAEHEGAJCBDAAB 2025-10-31
# 1618        NaN   BAF52LNCFAABFJF    RABADHHIBJ  ABJADHHIBJHABAAB 2025-10-31
# 4968        NaN   CCB52LNCFAAAGFH    RABADJDEAG  AFHADJDEAGCBDAAB 2025-09-30
#
# [5 rows x 28 columns]

# %%
# Missing value analysis

missing_summary = df.isnull().sum().sort_values(ascending=False)
missing_summary
# Out:
# NO_OF_POS_TXNS        17432
# FONELOAN_OS           17409
# FD_AMT                17151
# NO_OF_QR_TXNS         17004
# CC_OS                 16668
# COLLATERAL_TYPE       16236
# MONTHLY_AVG_CR_AMT    11009
# OVD_AMT               10636
# REP_FREQ              10449
# LOAN_TENURE_MONTHS    10449
# MONTHLY_AVG_DR_AMT    10257
# MONTHLY_NO_OF_TXNS    10160
# PROFESSION              765
# PROVINCE                114
# DISTRICT                114
# INTTRATE                  0
# SCHM_TYPE                 0
# ACCT_OPN_DATE             0
# SANCT_LIM                 0
# PREPAYMENT_HIST           0
# MONTHLY_AVG_DEP           0
# CUST_DOB                  0
# DORMANT_STATUS            0
# RISK_RATING               0
# MAPPED_FORACID            0
# MAPPED_CIF_ID             0
# MAPPED_OP_AC              0
# AS_ON                     0
# dtype: int64

# %% [markdown]
# ### 1. Exploratory Data Analysis

# %% [markdown]
# #### Chekcking missing values

# %%
round (df.isnull().sum()/len(df.index)*100,2)
# Out:
# ACCT_OPN_DATE          0.00
# SCHM_TYPE              0.00
# SANCT_LIM              0.00
# COLLATERAL_TYPE       92.72
# LOAN_TENURE_MONTHS    59.67
# REP_FREQ              59.67
# INTTRATE               0.00
# PREPAYMENT_HIST        0.00
# OVD_AMT               60.74
# CUST_DOB               0.00
# MONTHLY_AVG_DEP        0.00
# FD_AMT                97.94
# MONTHLY_AVG_CR_AMT    62.87
# MONTHLY_AVG_DR_AMT    58.57
# MONTHLY_NO_OF_TXNS    58.02
# DISTRICT               0.65
# PROVINCE               0.65
# PROFESSION             4.37
# RISK_RATING            0.00
# DORMANT_STATUS         0.00
# NO_OF_QR_TXNS         97.10
# NO_OF_POS_TXNS        99.55
# FONELOAN_OS           99.42
# CC_OS                 95.19
# MAPPED_FORACID         0.00
# MAPPED_CIF_ID          0.00
# MAPPED_OP_AC           0.00
# AS_ON                  0.00
# dtype: float64

# %% [markdown]
# Observation : We have missing values in the few columns

# %% [markdown]
# ### 1A. Graphical Univariate Analysis

# %%
# importing library for visualization

# Makes plots appear inline in notebooks
# %matplotlib inline

# Install seaborn if not already installed
# %pip install seaborn

# importing library
import matplotlib.pyplot as plt
import seaborn as sns

# Apply Seaborn's whitegrid style for nicer-looking plots
sns.set(style="whitegrid")

# %%
# creating a tuple that consists of a list of all the columns in the dataframe 'df'

feature = df.columns

# %%
# displaying all the features here for better understanding

for i in enumerate (feature):
    print(i)
# Out:
# (0, 'ACCT_OPN_DATE')
# (1, 'SCHM_TYPE')
# (2, 'SANCT_LIM')
# (3, 'COLLATERAL_TYPE')
# (4, 'LOAN_TENURE_MONTHS')
# (5, 'REP_FREQ')
# (6, 'INTTRATE')
# (7, 'PREPAYMENT_HIST')
# (8, 'OVD_AMT')
# (9, 'CUST_DOB')
# (10, 'MONTHLY_AVG_DEP')
# (11, 'FD_AMT')
# (12, 'MONTHLY_AVG_CR_AMT')
# (13, 'MONTHLY_AVG_DR_AMT')
# (14, 'MONTHLY_NO_OF_TXNS')
# (15, 'DISTRICT')
# (16, 'PROVINCE')
# (17, 'PROFESSION')
# (18, 'RISK_RATING')
# (19, 'DORMANT_STATUS')
# (20, 'NO_OF_QR_TXNS')
# (21, 'NO_OF_POS_TXNS')
# (22, 'FONELOAN_OS')
# (23, 'CC_OS')
# (24, 'MAPPED_FORACID')
# (25, 'MAPPED_CIF_ID')
# (26, 'MAPPED_OP_AC')
# (27, 'AS_ON')

# %%
import math

numeric_cols = df.select_dtypes(include=['int64', 'float64']).columns

num_plots = len(numeric_cols)
rows = math.ceil(num_plots / 3)  # 3 columns per row
cols = 3

plt.figure(figsize=(5*cols, 4*rows))

# adding number to each feature of the list 'feature' to make use of subplot funcionality using enumerate
# plotting all the variables together to have the idea of how the values in each variables are distributed

for i, col in enumerate(numeric_cols):
    plt.subplot(rows, cols, i+1)
    sns.histplot(df[col], kde=True, color='skyblue')
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# #### Initial Observations

# %% [markdown]
# * The variables 'life_expec', 'total_fer', 'gdpp','income' and 'child_mort' seem to have more predictive power than the other variables based on the shape of the graph and the variance in data we can observe

# %% [markdown]
# ### 1B. Graphical Bivariate Analysis

# %%
# Basic univariate statistics for numerical features
num_stats = df[numerical_cols].describe().T
num_stats
# Out:
#                       count          mean           std         min       25%  \
# SANCT_LIM           17511.0  6.354808e+05  1.550879e+06        0.00      0.00
# LOAN_TENURE_MONTHS   7062.0  9.629142e+01  8.479340e+01        0.00     10.00
# INTTRATE            17511.0  4.962947e+00  3.677531e+00       -0.25      0.00
# OVD_AMT              6875.0  1.361168e+04  2.974564e+05 -4899823.21      0.00
# MONTHLY_AVG_DEP     17511.0 -1.419786e+03  4.581699e+05 -5000000.00      1.44
# FD_AMT                360.0  1.232863e+06  2.624927e+06        0.00      0.00
# MONTHLY_AVG_CR_AMT   6502.0  7.880844e+04  4.607789e+05        0.00  10000.00
# MONTHLY_AVG_DR_AMT   7254.0  3.793177e+04  1.821144e+05        0.00   5746.00
# MONTHLY_NO_OF_TXNS   7351.0  5.704394e+00  1.240489e+01        1.00      2.00
# NO_OF_QR_TXNS         507.0  6.051282e+00  7.940573e+00        1.00      1.00
# NO_OF_POS_TXNS         79.0  2.734177e+00  2.335396e+00        1.00      1.00
# FONELOAN_OS           102.0  4.770456e+04  5.949736e+04     4652.00  10566.00
# CC_OS                 843.0  1.401033e+04  3.616396e+04   -31199.29      0.00
#
#                          50%         75%          max
# SANCT_LIM               0.00  700000.000  25000000.00
# LOAN_TENURE_MONTHS     84.00     180.000       480.00
# INTTRATE                5.75       7.750        18.00
# OVD_AMT                 0.00   16319.265   6221485.04
# MONTHLY_AVG_DEP       561.77    4821.590   5738147.63
# FD_AMT              15000.00  875544.250  15700000.00
# MONTHLY_AVG_CR_AMT  19437.50   40000.000  15800000.00
# MONTHLY_AVG_DR_AMT  12166.00   25000.000   5682673.00
# MONTHLY_NO_OF_TXNS      3.00       4.000       296.00
# NO_OF_QR_TXNS           3.00       8.000        60.00
# NO_OF_POS_TXNS          2.00       3.000        11.00
# FONELOAN_OS         19982.00   42382.000    205000.00
# CC_OS                   0.00    1687.230    259935.42

# %% [markdown]
# #### Observations

# %% [markdown]
# * 'child_mort' is highly correlated with 'life_expec'
# * 'total_fer' is also highly correlated with 'child_mort'
# *  We can just use 'child_mort' and not loose a significant predictive power of 'life_expec' and 'total_fer'
# *  The selection will make clustering easier

# %% [markdown]
# #### Final Variables

# %% [markdown]
# * Based on the observations from univariate and bivariate analysis, we are selecting the follwing varaibles:
#        1. 'child_mort'
#        2. 'income'
#        3. 'gdpp'

# %% [markdown]
# ### 1C. Numeric Univarite Analysis and Outlier Treatment

# %% [markdown]
# #### Variable One : chid_mort

# %%
# 'child_mort' expresses the death of children under the age of 5 per 1000 live births in a specific country

# %%
df.child_mort.describe()
# Out:
# count    167.000000
# mean      38.270060
# std       40.328931
# min        2.600000
# 25%        8.250000
# 50%       19.300000
# 75%       62.100000
# max      208.000000
# Name: child_mort, dtype: float64

# %%
# plotting is distplot to understand the variable 'child_mort'

sns.boxplot(df['child_mort'])
plt.show()

# %%
# we can notice some outliers

# %%
# value at the 90th percentile

df.child_mort.quantile(0.9)
# Out:
# 100.22

# %% [markdown]
# We will keep the outliers in the case because there might be countries where the health situation is very bad. These are the kind of countries we are targetting. So the outlier information becomes important in case of this variable and we can not remove them

# %% [markdown]
# #### Variable Two : income

# %%
# 'income' expresses the net income per person in a specific country

# %%
df.income.describe()
# Out:
# count       167.000000
# mean      17144.688623
# std       19278.067698
# min         609.000000
# 25%        3355.000000
# 50%        9960.000000
# 75%       22800.000000
# max      125000.000000
# Name: income, dtype: float64

# %%
# plotting is distplot to understand the variable 'income'

sns.boxplot(df['income'])
plt.show()

# %%
# we notice some outiers

# %%
# value at the 90th percentile

income_q = df.income.quantile(0.9)

# %% [markdown]
# The higher values of net income in a country does not add value to our problem statement. Those countries will not fall in the category of countries we can recommend the CEO to focus on.

# %%
# capping the at outliers at 90th percentile

df.income[df.income > 42000] = income_q

# %%
# checking the new details of the variable

df.income.describe()
# Out:
# count      167.000000
# mean     15217.263473
# std      13726.451022
# min        609.000000
# 25%       3355.000000
# 50%       9960.000000
# 75%      22800.000000
# max      41400.000000
# Name: income, dtype: float64

# %% [markdown]
# #### Variable Three : gdpp

# %%
# 'gdpp' expresses the GDP per capita in a specific country

# %%
df.gdpp.describe()
# Out:
# count       167.000000
# mean      12964.155689
# std       18328.704809
# min         231.000000
# 25%        1330.000000
# 50%        4660.000000
# 75%       14050.000000
# max      105000.000000
# Name: gdpp, dtype: float64

# %%
# plotting is distplot to understand the variable 'gdpp'

sns.boxplot(df['gdpp'])
plt.show()

# %%
# we notice some outliers

# %%
# value at the 90th percentile

gdpp_q = df.gdpp.quantile(0.9)

# %% [markdown]
# Similar to net income, the higher values of GDP per capita in a country does not add value to our problem statement. Those countries will not fall in the category of countries we can recommend the CEO to focus on.

# %%
# # capping the at outliers at 90th percentile

df.gdpp[df.gdpp > 27000] = gdpp_q

# %%
# checking the new details of the variable

df.gdpp.describe()
# Out:
# count      167.000000
# mean     11938.167665
# std      14765.641532
# min        231.000000
# 25%       1330.000000
# 50%       4660.000000
# 75%      14050.000000
# max      41840.000000
# Name: gdpp, dtype: float64

# %% [markdown]
# ## 2. Hopkins Score

# %% [markdown]
# #### Checking the Hopkins Score

# %%
# importing the relevant packages

from sklearn.neighbors import NearestNeighbors
from random import sample
from numpy.random import uniform
import numpy as np
from math import isnan
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 3
#       1 # importing the relevant packages
# ----> 3 from sklearn.neighbors import NearestNeighbors
#       4 from random import sample
#       5 from numpy.random import uniform
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# Calculating the Hopkins score by using an external library

def hopkins(X):
    d = X.shape[1]
    n = len(X)
    m = int(0.1 * n)
    nbrs = NearestNeighbors(n_neighbors=1).fit(X.values)

    rand_X = sample(range(0, n, 1), m)

    ujd = []
    wjd = []
    for j in range(0, m):
        u_dist, _ = nbrs.kneighbors(uniform(np.amin(X,axis=0),np.amax(X,axis=0),d).reshape(1, -1), 2, return_distance=True)
        ujd.append(u_dist[0][1])
        w_dist, _ = nbrs.kneighbors(X.iloc[rand_X[j]].values.reshape(1, -1), 2, return_distance=True)
        wjd.append(w_dist[0][1])

    H = sum(ujd) / (sum(ujd) + sum(wjd))
    if isnan(H):
        print(ujd, wjd)
        H = 0

    return H

# %%
# creating a new dataframe with only the selected columns for clustering

df1 = df.drop(['country'], axis = 1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 3
#       1 # creating a new dataframe with only the selected columns for clustering
# ----> 3 df1 = df.drop(['country'], axis = 1)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['country'] not found in axis"

# %%
df1.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 df1.head()
#
# NameError: name 'df1' is not defined

# %%
# Calcualting the hopkins score multiple times to check for the different values that the hopkins score might take

(for i in range (1,11):
    print(hopkins(df1)))
# Out:
# 0.9364327025884164
# 0.9404123802485471
# 0.9396091673030446
# 0.9231867475814011
# 0.9395231282054961
# 0.9178053259692266
# 0.8695554556533871
# 0.9125676881286339
# 0.8718996001684429
# 0.9264353332712969

# %% [markdown]
# The Hopkins score is greater that 80 percentage even after runining it more than 10 times. So we can understand that the data has good clustering tendency

# %% [markdown]
# ## 3. Scaling

# %%
# importing relevant library

# %pip install -U scikit-learn

from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

df2 = scaler.fit_transform(df1)


df2 = pd.DataFrame(df2, columns = df1.columns[:])

df2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 3
#       1 scaler = StandardScaler()
# ----> 3 df2 = scaler.fit_transform(df1)
#       6 df2 = pd.DataFrame(df2, columns = df1.columns[:])
#       8 df2.head()
#
# NameError: name 'df1' is not defined

# %% [markdown]
# ## 4. K Means CLustering

# %% [markdown]
# #### Choosing the value of K with Silhouttee Score

# %%
# importing revelant libraries

from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans

# %%
ss = []
for k in range(2, 11):
    kmean = KMeans(n_clusters = k).fit(df2)
    ss.append([k, silhouette_score(df2, kmean.labels_)])

temp = pd.DataFrame(ss)
plt.plot(temp[0], temp[1])
plt.show()

# %% [markdown]
# #### Note :
# 1. Though the peak value of silhouttee score is in between 3 and 4
# 2. We will check the Elbow curve before making a conclusion on the number of clusters

# %% [markdown]
# #### Choosing the value of K with Elbow curve

# %%
ssd = []
for k in range(2, 11):
    kmean = KMeans(n_clusters = k).fit(df2)
    ssd.append([k, kmean.inertia_])

temp = pd.DataFrame(ssd)
plt.plot(temp[0], temp[1])
plt.show()

# %% [markdown]
# Note:
# 1. In this curve we have a break point at 3,4 and 6
# 2. In elbow curve we prefer choosing the lesser clusters in case of multiple bends

# %% [markdown]
# Note:
#
# We choose the value of 3 and 4 based on both the plots

# %% [markdown]
# ### 4A. Clustering : Creating 3 different clusters

# %%
# creating 3 different clusters

kmean = KMeans(n_clusters = 3, random_state = 100)
kmean.fit(df2)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=100, tol=0.0001, verbose=0)

# %%
# creating the dataframe from the output we got from K Mean algorithm

cluster_3  = pd.DataFrame(kmean.labels_, columns= ['cluster_3'])
cluster_3.head()
# Out:
#    cluster_3
# 0          2
# 1          1
# 2          1
# 3          2
# 4          1

# %%
# concatinating the dataframe :  clusters_1 and kmean

df_kmean = pd.concat([df, cluster_3], axis =1)
df_kmean.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp  cluster_3
# 0       9.44        56.2       5.82    553          2
# 1       4.49        76.3       1.65   4090          1
# 2      16.10        76.5       2.89   4460          1
# 3      22.40        60.1       6.16   3530          2
# 4       1.44        76.8       2.13  12200          1

# %%
# checking the value counts in each cluster

df_kmean.cluster_3.value_counts()
# Out:
# 1    83
# 2    45
# 0    39
# Name: cluster_3, dtype: int64

# %% [markdown]
# ### 4B. Cluster Profiling based on K Means Clustering , k=3

# %%
plt.figure(figsize = [20,5])

plt.subplot(1,3,1)
sns.boxplot(x= 'cluster_3', y ='child_mort', data = df_kmean)

plt.subplot(1,3,2)
sns.boxplot(x= 'cluster_3', y ='income', data = df_kmean)

plt.subplot(1,3,3)
sns.boxplot(x= 'cluster_3', y ='gdpp', data = df_kmean)

plt.show()

# %% [markdown]
# #### Properties of Different Clusters

# %% [markdown]
# 1. Cluster 2 has very high child mortality, low net income per person and very low GDP per capita
# 2. Cluster 1 has medium range child mortality , medium range net income per person and low GDP per capita
# 3. Cluster 0 has low child mortality , high net income per person and high GDP per capita

# %%
# Note : The cluster of our interest is cluster 2

# %% [markdown]
# ### 4C. Focus Countries based on K Mean Clustering , k=3

# %%
df_kmean[df_kmean['cluster_3'] == 2].shape
# Out:
# (45, 11)

# %%
# We have 46 countries that fall in this category

# %%
# countries that fall into this category

df_kmean[df_kmean['cluster_3'] == 2].country
# Out:
# 0                   Afghanistan
# 3                        Angola
# 17                        Benin
# 25                 Burkina Faso
# 26                      Burundi
# 28                     Cameroon
# 31     Central African Republic
# 32                         Chad
# 36                      Comoros
# 37             Congo, Dem. Rep.
# 38                  Congo, Rep.
# 40                Cote d'Ivoire
# 49            Equatorial Guinea
# 50                      Eritrea
# 55                        Gabon
# 56                       Gambia
# 59                        Ghana
# 63                       Guinea
# 64                Guinea-Bissau
# 66                        Haiti
# 80                        Kenya
# 81                     Kiribati
# 84                          Lao
# 87                      Lesotho
# 88                      Liberia
# 93                   Madagascar
# 94                       Malawi
# 97                         Mali
# 99                   Mauritania
# 106                  Mozambique
# 108                     Namibia
# 112                       Niger
# 113                     Nigeria
# 116                    Pakistan
# 126                      Rwanda
# 129                     Senegal
# 132                Sierra Leone
# 137                South Africa
# 142                       Sudan
# 147                    Tanzania
# 149                 Timor-Leste
# 150                        Togo
# 155                      Uganda
# 165                       Yemen
# 166                      Zambia
# Name: country, dtype: object

# %%
# sorting the countries to find the top 5 countries to focus on

df_kmean[df_kmean['cluster_3'] == 2].sort_values(by = ['child_mort','income','gdpp'] , ascending = [False, True, True]).head(5)
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 66                      Haiti       208.0     15.3    6.91     64.7    1500
# 132              Sierra Leone       160.0     16.8   13.10     34.5    1220
# 32                       Chad       150.0     36.8    4.53     43.5    1930
# 31   Central African Republic       149.0     11.8    3.98     26.5     888
# 97                       Mali       137.0     22.8    4.98     35.1    1870
#
#      inflation  life_expec  total_fer  gdpp  cluster_3
# 66        5.45        32.1       3.33   662          2
# 132      17.20        55.0       5.20   399          2
# 32        6.39        56.5       6.59   897          2
# 31        2.01        47.5       5.21   446          2
# 97        4.37        59.5       6.55   708          2

# %% [markdown]
# #### The countries we can recommend the CEO to focus on based on K Means clustering as k = 3 are

# %% [markdown]
# 1. Haiti
# 2. Sierra Leone
# 3. Chad
# 4. Central African Republic
# 5. Mali

# %% [markdown]
# ### 4D. Creating 4 different clusters

# %%
# creating 4 different clusters

kmean = KMeans(n_clusters = 4, random_state = 100)
kmean.fit(df2)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=4, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=100, tol=0.0001, verbose=0)

# %%
# creating the dataframe from the output we got from K Mean algorithm

cluster_4  = pd.DataFrame(kmean.labels_, columns= ['cluster_4'])
cluster_4.head()
# Out:
#    cluster_4
# 0          2
# 1          0
# 2          0
# 3          2
# 4          0

# %%
# concatinating the dataframe :  clusters and kmean

df_kmean = pd.concat([df_kmean, cluster_4], axis =1)
df_kmean.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp  cluster_3  cluster_4
# 0       9.44        56.2       5.82    553          2          2
# 1       4.49        76.3       1.65   4090          1          0
# 2      16.10        76.5       2.89   4460          1          0
# 3      22.40        60.1       6.16   3530          2          2
# 4       1.44        76.8       2.13  12200          1          0

# %%
# checking the value counts in each cluster

df_kmean.cluster_4.value_counts()
# Out:
# 0    83
# 2    45
# 1    36
# 3     3
# Name: cluster_4, dtype: int64

# %% [markdown]
# ### 4E. Cluster Profiling based on K Means Clustering, k=4

# %%
plt.figure(figsize = [20,5])

plt.subplot(1,3,1)
sns.boxplot(x= 'cluster_4', y ='child_mort', data = df_kmean)

plt.subplot(1,3,2)
sns.boxplot(x= 'cluster_4', y ='income', data = df_kmean)

plt.subplot(1,3,3)
sns.boxplot(x= 'cluster_4', y ='gdpp', data = df_kmean)

plt.show()

# %% [markdown]
# 1. Cluster 0 has low child mortality, low net income per person and low GDP per capita
# 2. Cluster 1 has low range child mortality , high net income per person and high GDP per capita
# 3. Cluster 2 has high child mortality , very low net income per person and very low GDP per capita
# 4. Cluster 3 has low child mortality , high net income per person and high GDP per capita

# %%
# Note : cluster of interest is cluster 2

# %% [markdown]
# ### 4F. Focus Countries based on K Mean Clustering , k=4

# %%
df_kmean[df_kmean['cluster_4'] == 2].country
# Out:
# 0                   Afghanistan
# 3                        Angola
# 17                        Benin
# 25                 Burkina Faso
# 26                      Burundi
# 28                     Cameroon
# 31     Central African Republic
# 32                         Chad
# 36                      Comoros
# 37             Congo, Dem. Rep.
# 38                  Congo, Rep.
# 40                Cote d'Ivoire
# 49            Equatorial Guinea
# 50                      Eritrea
# 55                        Gabon
# 56                       Gambia
# 59                        Ghana
# 63                       Guinea
# 64                Guinea-Bissau
# 66                        Haiti
# 80                        Kenya
# 81                     Kiribati
# 84                          Lao
# 87                      Lesotho
# 88                      Liberia
# 93                   Madagascar
# 94                       Malawi
# 97                         Mali
# 99                   Mauritania
# 106                  Mozambique
# 108                     Namibia
# 112                       Niger
# 113                     Nigeria
# 116                    Pakistan
# 126                      Rwanda
# 129                     Senegal
# 132                Sierra Leone
# 137                South Africa
# 142                       Sudan
# 147                    Tanzania
# 149                 Timor-Leste
# 150                        Togo
# 155                      Uganda
# 165                       Yemen
# 166                      Zambia
# Name: country, dtype: object

# %%
# sorting the countries to find the top 5 countries to focus on

df_kmean[df_kmean['cluster_4'] == 2].sort_values(by = ['child_mort','income','gdpp'] , ascending = [False, True, True]).head(5)
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 66                      Haiti       208.0     15.3    6.91     64.7    1500
# 132              Sierra Leone       160.0     16.8   13.10     34.5    1220
# 32                       Chad       150.0     36.8    4.53     43.5    1930
# 31   Central African Republic       149.0     11.8    3.98     26.5     888
# 97                       Mali       137.0     22.8    4.98     35.1    1870
#
#      inflation  life_expec  total_fer  gdpp  cluster_3  cluster_4
# 66        5.45        32.1       3.33   662          2          2
# 132      17.20        55.0       5.20   399          2          2
# 32        6.39        56.5       6.59   897          2          2
# 31        2.01        47.5       5.21   446          2          2
# 97        4.37        59.5       6.55   708          2          2

# %% [markdown]
# #### The countries we can recommend the CEO to focus on based on K Means clustering as k = 4 are

# %% [markdown]
# 1. Haiti
# 2. Sierra Leone
# 3. Chad
# 4. Central African Republic
# 5. Mali

# %% [markdown]
# #### Note

# %% [markdown]
# We used the scaled dataframe with all the continuous columns in case of K means clustering because it was giving decent clusters. We have not done the same with Hierarchical Clustering as proper clusters were not forming. We have only used the selected variables for Hierarchical Clustering.

# %% [markdown]
# ## 5. Hierarchical Clustering

# %%
# importing relevant libraries

from scipy.cluster.hierarchy import linkage
from scipy.cluster.hierarchy import dendrogram
from scipy.cluster.hierarchy import cut_tree

# %%
# checking the scaled dataframe : This is the same dataframe we used in the K Means clustering

df2.head()
# Out:
#    child_mort   exports    health   imports    income  inflation  life_expec  \
# 0    1.291532 -1.138280  0.279088 -0.082455 -0.994298   0.157336   -1.619092
# 1   -0.538949 -0.479658 -0.097016  0.070837 -0.386346  -0.312347    0.647866
# 2   -0.272833 -0.099122 -0.966073 -0.641762 -0.169325   0.789274    0.670423
# 3    2.007808  0.775381 -1.448071 -0.165315 -0.680823   1.387054   -1.179234
# 4   -0.695634  0.160668 -0.286894  0.497568  0.283716  -0.601749    0.704258
#
#    total_fer      gdpp
# 0   1.902882 -0.773377
# 1  -0.859973 -0.533114
# 2  -0.038404 -0.507981
# 3   2.128151 -0.571154
# 4  -0.541946  0.017786

# %%
#getting the dataframe with the countries and the clusters derived from K Means Clustering

df_kmean.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp  cluster_3  cluster_4
# 0       9.44        56.2       5.82    553          2          2
# 1       4.49        76.3       1.65   4090          1          0
# 2      16.10        76.5       2.89   4460          1          0
# 3      22.40        60.1       6.16   3530          2          2
# 4       1.44        76.8       2.13  12200          1          0

# %%
# creating a new dataframe df_h for hierarchial clustering

df_h = df2.drop(['exports','health','imports','inflation','life_expec','total_fer'] , axis =1)

# %%
# Observing the new dataframe

df_h.head()
# Out:
#    child_mort    income      gdpp
# 0    1.291532 -0.994298 -0.773377
# 1   -0.538949 -0.386346 -0.533114
# 2   -0.272833 -0.169325 -0.507981
# 3    2.007808 -0.680823 -0.571154
# 4   -0.695634  0.283716  0.017786

# %% [markdown]
# #### Single Linkage

# %%
# Checking the clustering based on single linkage

output = linkage(df_h, method ='single',metric = 'euclidean')

# %%
dendrogram(output)
plt.show()

# %% [markdown]
# 1. It is very difficult to read the results based on single linkage
# 2. The formation of clusters do not seem to be appropriate

# %% [markdown]
# #### Complete linkage

# %%
output = linkage(df_h, method ='complete',metric = 'euclidean')

# %%
dendrogram(output)
plt.show()

# %% [markdown]
# 1. It is easier to read the result based on complete linkage
# 2. The formation of clusters seem appropriate

# %% [markdown]
# #### Choosing the number of clusters

# %%
# We are choosing to create 3 clusters based in reference to the above dendrogram

cut_tree(output, n_clusters = 3).shape
# Out:
# (167, 1)

# %%
# creating the array clusters_h

clusters_h = cut_tree(output, n_clusters = 3).reshape(-1,)

# %%
# Assigning a new column - 'clusters_h' to the df_kmean dataframe

df_kmean['clusters_h']= clusters_h

# %%
# Obaserivng the df_kmean dataframe

df_kmean.head()
# Out:
#                country  child_mort  exports  health  imports  income  \
# 0          Afghanistan        90.2     10.0    7.58     44.9    1610
# 1              Albania        16.6     28.0    6.55     48.6    9930
# 2              Algeria        27.3     38.4    4.17     31.4   12900
# 3               Angola       119.0     62.3    2.85     42.9    5900
# 4  Antigua and Barbuda        10.3     45.5    6.03     58.9   19100
#
#    inflation  life_expec  total_fer   gdpp  cluster_3  cluster_4  clusters_h
# 0       9.44        56.2       5.82    553          2          2           0
# 1       4.49        76.3       1.65   4090          1          0           0
# 2      16.10        76.5       2.89   4460          1          0           0
# 3      22.40        60.1       6.16   3530          2          2           1
# 4       1.44        76.8       2.13  12200          1          0           0

# %% [markdown]
# #### Ploting the clusters

# %%
plt.figure(figsize = [20,5])

plt.subplot(1,3,1)
sns.boxplot(x= 'clusters_h', y ='child_mort', data = df_kmean)

plt.subplot(1,3,2)
sns.boxplot(x= 'clusters_h', y ='income', data = df_kmean)

plt.subplot(1,3,3)
sns.boxplot(x= 'clusters_h', y ='gdpp', data = df_kmean)

plt.show()

# %% [markdown]
# 1. Cluster 0 has medium range child mortality , medium range net income per person and medium GDP per capita
# 2. Cluster 1 has very high child mortality, very low net income per person and very low GDP per capita
# 3. Cluster 2 has low child mortality , high net income per person and high GDP per capita

# %%
# Note : The cluster of our interest is cluster 1

# %%
# checking the countries in cluster 1

df_kmean[df_kmean['clusters_h'] == 1]
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 3                      Angola       119.0     62.3    2.85     42.9    5900
# 17                      Benin       111.0     23.8    4.10     37.2    1820
# 25               Burkina Faso       116.0     19.2    6.74     29.6    1430
# 28                   Cameroon       108.0     22.2    5.13     27.0    2660
# 31   Central African Republic       149.0     11.8    3.98     26.5     888
# 32                       Chad       150.0     36.8    4.53     43.5    1930
# 37           Congo, Dem. Rep.       116.0     41.1    7.91     49.6     609
# 40              Cote d'Ivoire       111.0     50.6    5.30     43.3    2690
# 63                     Guinea       109.0     30.3    4.93     43.2    1190
# 64              Guinea-Bissau       114.0     14.9    8.50     35.2    1390
# 66                      Haiti       208.0     15.3    6.91     64.7    1500
# 97                       Mali       137.0     22.8    4.98     35.1    1870
# 112                     Niger       123.0     22.2    5.16     49.1     814
# 113                   Nigeria       130.0     25.3    5.07     17.4    5150
# 132              Sierra Leone       160.0     16.8   13.10     34.5    1220
#
#      inflation  life_expec  total_fer  gdpp  cluster_3  cluster_4  clusters_h
# 3       22.400        60.1       6.16  3530          2          2           1
# 17       0.885        61.8       5.36   758          2          2           1
# 25       6.810        57.9       5.87   575          2          2           1
# 28       1.910        57.3       5.11  1310          2          2           1
# 31       2.010        47.5       5.21   446          2          2           1
# 32       6.390        56.5       6.59   897          2          2           1
# 37      20.800        57.5       6.54   334          2          2           1
# 40       5.390        56.3       5.27  1220          2          2           1
# 63      16.100        58.0       5.34   648          2          2           1
# 64       2.970        55.6       5.05   547          2          2           1
# 66       5.450        32.1       3.33   662          2          2           1
# 97       4.370        59.5       6.55   708          2          2           1
# 112      2.550        58.8       7.49   348          2          2           1
# 113    104.000        60.5       5.84  2330          2          2           1
# 132     17.200        55.0       5.20   399          2          2           1

# %%
# sorting the countries to find the top 5 countries to focus on

df_kmean[df_kmean['clusters_h'] == 1].sort_values(by = ['child_mort','income','gdpp'] , ascending = [False, True, True]).head(5)
# Out:
#                       country  child_mort  exports  health  imports  income  \
# 66                      Haiti       208.0     15.3    6.91     64.7    1500
# 132              Sierra Leone       160.0     16.8   13.10     34.5    1220
# 32                       Chad       150.0     36.8    4.53     43.5    1930
# 31   Central African Republic       149.0     11.8    3.98     26.5     888
# 97                       Mali       137.0     22.8    4.98     35.1    1870
#
#      inflation  life_expec  total_fer  gdpp  cluster_3  cluster_4  clusters_h
# 66        5.45        32.1       3.33   662          2          2           1
# 132      17.20        55.0       5.20   399          2          2           1
# 32        6.39        56.5       6.59   897          2          2           1
# 31        2.01        47.5       5.21   446          2          2           1
# 97        4.37        59.5       6.55   708          2          2           1

# %% [markdown]
# #### The countries we can recommend the CEO to focus on based on Hierarchial clustering are

# %% [markdown]
# 1. Haiti
# 2. Sierra Leone
# 3. Chad
# 4. Central African Republic
# 5. Mali

# %% [markdown]
# ## 6. Final Recommendation

# %% [markdown]
# We found the same focus countries based on both K Means clutsering and Hierarchial Clustering.

# %% [markdown]
# #### The focus countires

# %% [markdown]
# 1. Haiti
# 2. Sierra Leone
# 3. Chad
# 4. Central African Republic
# 5. Mali
